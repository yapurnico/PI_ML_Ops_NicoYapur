# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pandas import json_normalize
import ast

# %%
movies_df = pd.read_csv("ETL_movies_main.csv")

# %%
# Eliminando duplicados porque afectan a revenue y valores de conteos o sumas
movies_df = movies_df.drop_duplicates(keep="first")

# %%
movies_df.shape
# Out:
# (45346, 20)

# %%
# getting columns needed
df_productions = movies_df.loc[:,["Movie_id","production_companies","production_countries"]]

# %%
# Turning NaN values into empty lists
df_productions['production_companies'] = df_productions['production_companies'].fillna('[]')

# %%
# str to dict
df_productions['production_companies'] = df_productions['production_companies'].apply(ast.literal_eval)

# %%
# exploding and checking
df_exploded = df_productions.explode('production_companies', ignore_index=True)
df_exploded
# Out:
#        Movie_id                               production_companies  \
# 0           862       {'name': 'Pixar Animation Studios', 'id': 3}
# 1          8844            {'name': 'TriStar Pictures', 'id': 559}
# 2          8844               {'name': 'Teitler Film', 'id': 2550}
# 3          8844  {'name': 'Interscope Communications', 'id': 10...
# 4         15602               {'name': 'Warner Bros.', 'id': 6194}
# ...         ...                                                ...
# 82233     30840  {'name': 'CanWest Global Communications', 'id'...
# 82234    111109               {'name': 'Sine Olivia', 'id': 19653}
# 82235     67758    {'name': 'American World Pictures', 'id': 6165}
# 82236    227506                 {'name': 'Yermoliev', 'id': 88753}
# 82237    461257                                                NaN
#
#                                     production_countries
# 0      [{'iso_3166_1': 'US', 'name': 'United States o...
# 1      [{'iso_3166_1': 'US', 'name': 'United States o...
# 2      [{'iso_3166_1': 'US', 'name': 'United States o...
# 3      [{'iso_3166_1': 'US', 'name': 'United States o...
# 4      [{'iso_3166_1': 'US', 'name': 'United States o...
# ...                                                  ...
# 82233  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...
# 82234      [{'iso_3166_1': 'PH', 'name': 'Philippines'}]
# 82235  [{'iso_3166_1': 'US', 'name': 'United States o...
# 82236           [{'iso_3166_1': 'RU', 'name': 'Russia'}]
# 82237   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]
#
# [82238 rows x 3 columns]

# %%
# Separating names and ids
df_exploded['company_name'] = df_exploded['production_companies'].apply(lambda x: x.get('name', '') if isinstance(x, dict) else '')
df_exploded['company_id'] = df_exploded['production_companies'].apply(lambda x: x.get('id', '') if isinstance(x, dict) else '')

# %%
# Joining exploded with original df
df_productions = df_productions.join(df_exploded[['company_name', 'company_id']])

# %%
df_productions
# Out:
#        Movie_id                               production_companies  \
# 0           862     [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1          8844  [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2         15602  [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 3         31357  [{'name': 'Twentieth Century Fox Film Corporat...
# 4         11862  [{'name': 'Sandollar Productions', 'id': 5842}...
# ...         ...                                                ...
# 45341     30840  [{'name': 'Westdeutscher Rundfunk (WDR)', 'id'...
# 45342    111109             [{'name': 'Sine Olivia', 'id': 19653}]
# 45343     67758  [{'name': 'American World Pictures', 'id': 6165}]
# 45344    227506               [{'name': 'Yermoliev', 'id': 88753}]
# 45345    461257                                                 []
#
#                                     production_countries  \
# 0      [{'iso_3166_1': 'US', 'name': 'United States o...
# 1      [{'iso_3166_1': 'US', 'name': 'United States o...
# 2      [{'iso_3166_1': 'US', 'name': 'United States o...
# 3      [{'iso_3166_1': 'US', 'name': 'United States o...
# 4      [{'iso_3166_1': 'US', 'name': 'United States o...
# ...                                                  ...
# 45341  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...
# 45342      [{'iso_3166_1': 'PH', 'name': 'Philippines'}]
# 45343  [{'iso_3166_1': 'US', 'name': 'United States o...
# 45344           [{'iso_3166_1': 'RU', 'name': 'Russia'}]
# 45345   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]
#
#                     company_name company_id
# 0        Pixar Animation Studios          3
# 1               TriStar Pictures        559
# 2                   Teitler Film       2550
# 3      Interscope Communications      10201
# 4                   Warner Bros.       6194
# ...                          ...        ...
# 45341           Trimark Pictures       4063
# 45342              Haut et Court        726
# 45343   Mille et Une Productions       2566
# 45344        Propaganda Pictures       2682
# 45345           Need Productions       6004
#
# [45346 rows x 5 columns]

# %%
# dropping unnecesary column
df_productions.drop(["production_companies"],axis=1,inplace=True)

# %%
# Transforming NaN values into empty lists
df_productions['production_countries'] = df_productions['production_countries'].fillna('[]')

# %%
# str to list of dictionaries
df_productions['production_countries'] = df_productions['production_countries'].apply(ast.literal_eval)

# %%
# Unnesting/exploding production_countries
df_exploded2 = df_productions.explode('production_countries')

def extract_country_info(x):
    if isinstance(x, dict):
        return pd.Series([x.get('iso_3166_1', ''), x.get('name', '')])
    else:
        return pd.Series(['', ''])

df_exploded2[['country_code', 'country_name']] = df_exploded2['production_countries'].apply(extract_country_info)

# %%
# Joining df_exploded to original df
df_productions = df_productions.join(df_exploded2[['country_code', 'country_name']])

# %%
# Dropping unnecesary columns
df_productions.drop(["production_countries"],axis=1,inplace=True)

# %%
df_productions
# Out:
#        Movie_id               company_name company_id country_code  \
# 0           862    Pixar Animation Studios          3           US
# 1          8844           TriStar Pictures        559           US
# 2         15602               Teitler Film       2550           US
# 3         31357  Interscope Communications      10201           US
# 4         11862               Warner Bros.       6194           US
# ...         ...                        ...        ...          ...
# 45341     30840           Trimark Pictures       4063           US
# 45342    111109              Haut et Court        726           PH
# 45343     67758   Mille et Une Productions       2566           US
# 45344    227506        Propaganda Pictures       2682           RU
# 45345    461257           Need Productions       6004           GB
#
#                    country_name
# 0      United States of America
# 1      United States of America
# 2      United States of America
# 3      United States of America
# 4      United States of America
# ...                         ...
# 45341  United States of America
# 45342               Philippines
# 45343  United States of America
# 45344                    Russia
# 45345            United Kingdom
#
# [55561 rows x 5 columns]

# %%
# It seems like the Movies are been made in more than 1 country
df_productions.sort_values('Movie_id',ascending=True)
# Out:
#        Movie_id             company_name company_id country_code  \
# 4337          2    Ministry of Film, The      21085           FI
# 12938         3     August Entertainment       3322           FI
# 17            5                Worldwide      55873           US
# 474           6       Universal Pictures         33           US
# 474           6       Universal Pictures         33           JP
# ...         ...                      ...        ...          ...
# 45156    467731  Red Wagon Entertainment      14440           US
# 21854    468343           France2 Cinéma       7089           FI
# 45280    468707              Finos Films      12991           FI
# 20161    469172       Rhône-Alpes Cinéma       1666           FR
# 20161    469172       Rhône-Alpes Cinéma       1666           PT
#
#                    country_name
# 4337                    Finland
# 12938                   Finland
# 17     United States of America
# 474    United States of America
# 474                       Japan
# ...                         ...
# 45156  United States of America
# 21854                   Finland
# 45280                   Finland
# 20161                    France
# 20161                  Portugal
#
# [55561 rows x 5 columns]

# %%
# df to csv

# %%
df_productions.to_csv("ETL_movies_productions.csv",index=False)
